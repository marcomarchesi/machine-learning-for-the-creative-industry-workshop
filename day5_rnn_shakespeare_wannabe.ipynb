# %%
import numpy as np
import os
import json
import random
import torch
import torch.nn as nn
from torch import Tensor
from urllib.request import urlopen  # Py3

from IPython.core.display import display, HTML

# %% [markdown]
# ## Text library

# %%
# TextLibrary class: text library for training, encoding, batch generation,
# and formatted source display
class TextLibrary:
    def __init__(self, descriptors, max=100000000):
        self.descriptors=descriptors
        self.data=''
        self.files=[]
        self.c2i = {}
        self.i2c = {}
        index = 1
        for descriptor in descriptors:
            fd={}
            if descriptor[:4] == 'http':
                try:
                    dat = urlopen(descriptor).read().decode('utf-8')
                    self.data += dat
                    fd["name"] = descriptor
                    fd["data"] = dat
                    fd["index"] = index
                    index += 1
                    self.files.append(fd)
                except Exception as e:
                    print(f"Can't download {descriptor}: {e}")
            else:
                fd["name"] = os.path.splitext(os.path.basename(descriptor))[0]
                try:
                    f = open(descriptor)
                    dat = f.read(max)
                    self.data += dat
                    fd["data"] = dat
                    fd["index"] = index
                    index += 1
                    self.files.append(fd)
                    f.close()
                except Exception as e:
                    print(f"ERROR: Cannot read: {filename}: {e}")
        ind = 0
        for c in self.data:  # sets are not deterministic
            if c not in self.c2i:
                self.c2i[c] = ind
                self.i2c[ind] = c
                ind += 1
        self.ptr = 0
            
    def print_colored_IPython(self, textlist, pre='', post=''):
        bgcolors = ['#d4e6f1', '#d8daef', '#ebdef0', '#eadbd8', '#e2d7d5', '#edebd0',
                    '#ecf3cf', '#d4efdf', '#d0ece7', '#d6eaf8', '#d4e6f1', '#d6dbdf',
                    '#f6ddcc', '#fae5d3', '#fdebd0', '#e5e8e8', '#eaeded', '#A9CCE3']
        out = ''
        for txt, ind in textlist:
            txt = txt.replace('\n','<br>')
            if ind==0:
                out += txt
            else:
                out += "<span style=\"background-color:"+bgcolors[ind%16]+";\">" + txt +\
                       "</span>"+"<sup>[" + str(ind) + "]</sup>"
        display(HTML(pre+out+post))
        
    def source_highlight(self, txt, minQuoteSize=10):
        tx = txt
        out = []
        qts = []
        txsrc=[("Sources: ", 0)]
        sc=False
        noquote = ''
        while len(tx)>0:  # search all library files for quote 'txt'
            mxQ = 0
            mxI = 0
            mxN = ''
            found = False
            for f in self.files:  # find longest quote in all texts
                p = minQuoteSize
                if p<=len(tx) and tx[:p] in f["data"]:
                    p = minQuoteSize + 1
                    while p<=len(tx) and tx[:p] in f["data"]:
                        p += 1
                    if p-1>mxQ:
                        mxQ = p-1
                        mxI = f["index"]
                        mxN = f["name"]
                        found = True
            if found:  # save longest quote for colorizing
                if len(noquote)>0:
                    out.append((noquote, 0))
                    noquote = ''
                out.append((tx[:mxQ],mxI))
                tx = tx[mxQ:]
                if mxI not in qts:  # create a new reference, if first occurence
                    qts.append(mxI)
                    if sc:
                        txsrc.append((", ", 0))
                    sc = True
                    txsrc.append((mxN,mxI))
            else:
                noquote += tx[0]
                tx = tx[1:]
        if len(noquote)>0:
            out.append((noquote, 0))
            noquote = ''
        self.print_colored_IPython(out)
        if len(qts)>0:  # print references, if there is at least one source
            self.print_colored_IPython(txsrc, pre="<small><p style=\"text-align:right;\">",
                                     post="</p></small>")
    
    def get_slice(self, length):
        if (self.ptr + length >= len(self.data)):
            self.ptr = 0
        if self.ptr == 0:
            rewind = True
        else:
            rewind = False
        sl = self.data[self.ptr:self.ptr+length]
        self.ptr += length
        return sl, rewind
    
    def decode(self, ar):
         return ''.join([self.i2c[ic] for ic in ar])
            
    def get_random_slice(self, length):
        p = random.randrange(0,len(self.data)-length)
        sl = self.data[p:p+length]
        return sl
    
    def get_slice_array(self, length):
        ar = np.array([c for c in self.get_slice(length)[0]],dtype=int)
        return ar
        
    def get_sample(self, length):
        s, rewind = self.get_slice(length+1)
        X = np.array([self.c2i[c] for c in s[:-1]],dtype=int)
        y = np.array([self.c2i[c] for c in s[1:]],dtype=int)
        return (X, y, rewind)
    
    def get_random_sample(self, length):
        s = self.get_random_slice(length+1)
        X = np.array([self.c2i[c] for c in s[:-1]],dtype=int)
        y = np.array([self.c2i[c] for c in s[1:]],dtype=int)
        return (X, y)
    
    def get_sample_batch(self, batch_size, length):
        smpX = np.zeros((batch_size,length),dtype=int)
        smpy = np.zeros((batch_size,length),dtype=int)
        for i in range(batch_size):
            smpX[i,:], smpy[i,:], _ = self.get_sample(length)
        return smpX, smpy
        
    def get_random_sample_batch(self, batch_size, length):
        smpX = np.zeros((batch_size,length),dtype=int)
        smpy = np.zeros((batch_size,length),dtype=int)
        for i in range(batch_size):
            smpX[i,:], smpy[i,:] = self.get_random_sample(length)
        return smpX, smpy

# %% [markdown]
# ## Model parameters and data sources

# %%
libdesc = {
    "name": "TinyShakespeare",
    "description": "Shakespeare's collected works from project Gutenberg",
    "lib": [
        'http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt',
    ]
}

textlib = TextLibrary(libdesc["lib"])

use_shakespeare = False

if use_shakespeare or not os.path.exists('data/lib.json'):
    # Default model parameters for shakespeare:
    model_params_shakespeare = {
        "model_name": "lib",
        "vocab_size": len(textlib.i2c),
        "neurons": 256,
        "layers": 2,
        "learning_rate": 1.e-3,
        "steps": 80,
        "batch_size": 128
    }
    model_params = model_params_shakespeare
else:        
    # Look for optional json description of a library:
    with open('data/lib.json') as data_file:    
        libdesc = json.load(data_file)
        textlib = TextLibrary(libdesc["lib"])
        model_params_lib = {
            "model_name": "lib",
            "vocab_size": len(textlib.i2c),
            "neurons": 512,
            "layers": 4,
            "learning_rate": 2.e-4,
            "steps": 80,
            "batch_size": 128
        }
        model_params = model_params_lib

# %%
def one_hot(p, dim):
    o=np.zeros(p.shape+(dim,), dtype=int)
    for y in range(p.shape[0]):
        for x in range(p.shape[1]):
            o[y,x,p[y,x]]=1
    return o

# %%
batch_size = model_params['batch_size']
vocab_size = model_params['vocab_size']
steps = model_params['steps']

force_cpu=False

if torch.cuda.is_available() and force_cpu is not True:
    device='cuda'
    use_cuda = True
    print("Running on GPU")
else:
    device='cpu'
    use_cuda = False
    print("Running on CPU")
    print("Note: on Google Colab, make sure to select:")
    print("      Runtime / Change Runtime Type / Hardware accelerator: GPU")

def get_data():
    X, y=textlib.get_random_sample_batch(batch_size, steps)
    Xo = one_hot(X, vocab_size)
    
    # Xt = Tensor(torch.from_numpy(np.array(Xo,dtype=np.float32)), requires_grad=False, dtype=torch.float32, device=device)
    # yt = Tensor(torch.from_numpy(y), requires_grad=False, dtype=torch.int32, device=device)
    Xt = Tensor(torch.from_numpy(np.array(Xo,dtype=np.float32))).to(device)
    Xt.requires_grad_(False)
    yt = torch.LongTensor(torch.from_numpy(np.array(y,dtype=np.int64))).to(device)
    yt.requires_grad_(False)
    return Xt, yt
# Out:
# Running on GPU

# %%
def show_gpu_mem(context="all"):
    if use_cuda:
        print("[{}] Memory allocated: {} max_alloc: {} cached: {} max_cached: {}".format(context,torch.cuda.memory_allocated(), torch.cuda.max_memory_allocated(), torch.cuda.memory_cached(), torch.cuda.max_memory_cached()))

# %% [markdown]
# ## The char-rnn model (deep LSTMs)

# %%
class Poet(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size, device):
        super(Poet, self).__init__()
        
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.output_size = output_size
        self.device=device
        
        self.lstm = nn.LSTM(input_size=input_size, hidden_size=hidden_size, num_layers=num_layers, batch_first=True, dropout=0)
        
        self.demb = nn.Linear(hidden_size, output_size)
        self.softmax = nn.Softmax(dim=-1)  # negative dims are a recent thing (as 2018-03), remove for old vers.
    
    def init_hidden(self, batch_size):
        self.h0 = torch.zeros(self.num_layers, batch_size, self.hidden_size, device=self.device)
        self.c0 = torch.zeros(self.num_layers, batch_size, self.hidden_size, device=self.device)

    def forward(self, inputx, steps):
        self.lstm.flatten_parameters()
        hn, (self.h0, self.c0) = self.lstm(inputx.to(self.device), (self.h0, self.c0))
        hnr = hn.contiguous().view(-1,self.hidden_size)
        op = self.demb(hnr)
        opr = op.view(-1, steps ,self.output_size)
        return opr

    def generate(self, n, start=None):
        s=''
        torch.set_grad_enabled(False)
        if start==None or len(start)==0:
            start=' '
        self.init_hidden(1)
        for c in start:
            X=np.array([[textlib.c2i[c]]])
            Xo=one_hot(X,self.output_size)
            Xt = Tensor(torch.from_numpy(np.array(Xo,dtype=np.float32))).to(self.device)
            ypl = self.forward(Xt,1)
            ypl2 = ypl.view(-1,self.output_size)
            yp = self.softmax(ypl2)
        for i in range(n):
            ypc=Tensor.cpu(yp.detach()) # .cpu()
            y_pred=ypc.numpy()
            inds=list(range(self.output_size))
            ind = np.random.choice(inds, p=y_pred.ravel())
            s=s+textlib.i2c[ind]
            X=np.array([[ind]])
            Xo=one_hot(X,self.output_size)
            Xt = Tensor(torch.from_numpy(np.array(Xo,dtype=np.float32))).to(self.device)
            ypl = self.forward(Xt,1)
            ypl2 = ypl.view(-1,self.output_size)
            yp = self.softmax(ypl2)
        torch.set_grad_enabled(True)
        return s

# %% [markdown]
# ## Create a poet

# %%
poet = Poet(vocab_size, model_params['neurons'], model_params['layers'], vocab_size, device).to(device)

# %% [markdown]
# ## Training helpers

# %%
criterion = nn.CrossEntropyLoss()
learning_rate = model_params['learning_rate']

opti = torch.optim.Adam(poet.parameters(),lr=learning_rate);

bok=0

def train(Xt, yt, bPr=False):
    poet.zero_grad()

    poet.init_hidden(Xt.size(0))
    output = poet(Xt, steps)
    
    olin=output.view(-1,vocab_size)
    _, ytp=torch.max(olin,1)
    ytlin=yt.view(-1)

    pr=0.0
    if bPr: # Calculate precision
        ok=0
        nok=0
        for i in range(ytlin.size()[0]):
            i1=ytlin[i].item()
            i2=ytp[i].item()
            if i1==i2:
                ok = ok + 1
            else:
                nok = nok+1
            pr=ok/(ok+nok)
            
    loss = criterion(olin, ytlin)
    ls = loss.item()
    loss.backward()
    opti.step()

    return ls, pr

# %% [markdown]
# ## The actual training

# %%
ls=0
nrls=0
if use_cuda:
    intv=250
else:
    intv=10
for e in range(2500000):
    Xt, yt = get_data()
    if (e+1)%intv==0:
        l,pr=train(Xt,yt,True)
    else:
        l,pr=train(Xt,yt,False)        
    ls=ls+l
    nrls=nrls+1
    if (e+1)%intv==0:
        print("Loss: {} Precision: {}".format(ls/nrls, pr))
        # if use_cuda:
        #    print("Memory allocated: {} max_alloc: {} cached: {} max_cached: {}".format(torch.cuda.memory_allocated(), torch.cuda.max_memory_allocated(), torch.cuda.memory_cached(), torch.cuda.max_memory_cached()))
        nrls=0
        ls=0
        tgen=poet.generate(500,"\n\n")
        textlib.source_highlight(tgen,10)
# Out:
# Loss: 3.255704989433289 Precision: 0.2521484375
# <br>  I le ‘i deo  ga heodranon  eohopyl n y  sanrateonu funed bodsnh de thel sbo’nouw s tfin
# Loss: 2.4498188133239744 Precision: 0.350390625
# <br>I nd tium haar torur dos’s cothinm Som, an. ANI Bhad a
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 2.169398317337036 Precision: 0.3958984375
# <br> Wher, wunt Therd dr
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 2.0434416241645814 Precision: 0.435546875
# <br>Thind by
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.9594793286323546 Precision: 0.4525390625
# <br>    Th</span><sup>[1]</sup>as sandl', gourdse<span style="background-color:#d8daef;">, with lig</span><sup>[1]</sup>riyfy, thus calcokere k
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.8975659966468812 Precision: 0.46064453125
# <br>    </span><sup>[1]</sup>it to lattear'd
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.8447654180526734 Precision: 0.447265625
# <br>    And </span><sup>[1]</sup>should Jornicers’d full comoundla. Huw h
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.8022566781044007 Precision: 0.48359375
# <br>See
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.7632980027198792 Precision: 0.4869140625
# <br>I he w<span style="background-color:#d8daef;">iting and </span><sup>[1]</sup>freal’
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.7289632000923156 Precision: 0.48662109375
# <br>And al</span><sup>[1]</sup>ow stri
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.6965673122406006 Precision: 0.51201171875
# <br>    m</span><sup>[1]</sup>estanning on endcentiont but <span style="background-color:#d8daef;">her, your </span><sup>[1]</sup>his lonks offund.
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.6696258521080016 Precision: 0.510546875
# <br>  WARQUEO. Wha
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.6417124342918397 Precision: 0.51005859375
# <br>Honpur t<span style="background-color:#d8daef;">row that t</span><sup>[1]</sup>o waid, thing,
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.616397126197815 Precision: 0.5298828125
# <br>As the</span><sup>[1]</sup>n if take<span style="background-color:#d8daef;">d the bread</span><sup>[1]</sup><span style="background-color:#d8daef;"> with this ind</span><sup>[1]</sup>erat'd
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.5954541869163512 Precision: 0.521484375
# <br>    an</span><sup>[1]</sup>d thin
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.5743368620872498 Precision: 0.53310546875
# <br>w</span><sup>[1]</sup>ay not lodys,<span style="background-color:#d8daef;"> well in the</span><sup>[1]</sup> filf'd pire dibry parnon
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.5554784007072449 Precision: 0.54033203125
# <br>  KING</span><sup>[1]</sup>
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.5383869190216064 Precision: 0.5416015625
# <br>  </span><sup>[1]</sup>  A<span style="background-color:#d8daef;">nd about the</span><sup>[1]</sup>
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.5220750260353089 Precision: 0.5625
# <br>  </span><sup>[1]</sup>CORAWNA<span style="background-color:#d8daef;">N. Have thou </span><sup>[1]</sup>wif<span style="background-color:#d8daef;">e will have</span><sup>[1]</sup>
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.505407793045044 Precision: 0.5607421875
# <br>    Be s</span><sup>[1]</sup>o leeve we w
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.4919890918731689 Precision: 0.559375
# <br>    W</span><sup>[1]</sup>i<span style="background-color:#d8daef;">th through </span><sup>[1]</sup>sonerncllow'r
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.477024534702301 Precision: 0.557421875
# <br>
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.467521065235138 Precision: 0.55849609375
# <br></span><sup>[1]</sup>No<span style="background-color:#d8daef;"> quoth the </span><sup>[1]</sup>su
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.453620198249817 Precision: 0.5693359375
# <br>    Wa</span><sup>[1]</sup>sk on
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.4470531501770019 Precision: 0.5681640625
# <br>                           </span><sup>[1]</sup>      Je mind, Might.
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.4349612398147582 Precision: 0.5705078125
# <br>    </span><sup>[1]</sup>So r
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.425355254650116 Precision: 0.56484375
# <br>    So </span><sup>[1]</sup>Ma
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.416916063785553 Precision: 0.58564453125
# <br>    </span><sup>[1]</sup>Do nost! Y<span style="background-color:#d8daef;">ous Hector </span><sup>[1]</sup>Jandone. But he ma
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.406871392726898 Precision: 0.57861328125
# <br>  CURIA. Axit
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.3994286775588989 Precision: 0.5890625
# <br>
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.3925196762084961 Precision: 0.5833984375
# <br>      And </span><sup>[1]</sup><span style="background-color:#d8daef;">his senten</span><sup>[1]</sup>s atti
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.3843580837249756 Precision: 0.5806640625
# <br>I
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.3785300645828247 Precision: 0.5990234375
# <br> </span><sup>[1]</sup>
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.369513699054718 Precision: 0.5833984375
# <br>    </span><sup>[1]</sup>My sut one's toa<span style="background-color:#d8daef;">th: I love</span><sup>[1]</sup>, but welcom
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.3637665090560913 Precision: 0.58779296875
# <br>    </span><sup>[1]</sup><span style="background-color:#d8daef;">FIRST WATC</span><sup>[1]</sup>ISIA. O,
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.3557679538726806 Precision: 0.5849609375
# <br>My salent In gr
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.3499893941879273 Precision: 0.58974609375
# <br>  </span><sup>[1]</sup>  Maje you’t my lifes
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.3453693375587463 Precision: 0.585546875
# <br>
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.339822769165039 Precision: 0.5923828125
# <br>See the
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.3339936695098877 Precision: 0.6041015625
# <br>    </span><sup>[1]</sup>W<span style="background-color:#d8daef;">hat neighb</span><sup>[1]</sup>s brining<span style="background-color:#d8daef;"> town with </span><sup>[1]</sup>I se
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.3298990368843078 Precision: 0.5994140625
# <br>    </span><sup>[1]</sup>How nower
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.32836759185791 Precision: 0.59951171875
# <br>    Th</span><sup>[1]</sup><span style="background-color:#d8daef;">at we with th</span><sup>[1]</sup>is timl
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.3209148054122926 Precision: 0.60673828125
# <br>Have </span><sup>[1]</sup><span style="background-color:#d8daef;">you all at </span><sup>[1]</sup>a
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.3171037216186523 Precision: 0.60302734375
# <br>    And</span><sup>[1]</sup> her rashes ar<span style="background-color:#d8daef;">our Caesar </span><sup>[1]</sup><span style="background-color:#d8daef;">and the Duke of </span><sup>[1]</sup>Cla
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.3125245246887207 Precision: 0.60712890625
# <br></span><sup>[1]</sup>Yourg, hope life?
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.3071202368736268 Precision: 0.59912109375
# <br>    </span><sup>[1]</sup>Th<span style="background-color:#d8daef;">e now our </span><sup>[1]</sup>f
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.3077496972084046 Precision: 0.605859375
# <br>    And as t</span><sup>[1]</sup>ears her, no mor
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.2998870558738709 Precision: 0.59638671875
# <br>    And make </span><sup>[1]</sup>the h
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.2987980780601502 Precision: 0.59794921875
# <br>  LEONTES. </span><sup>[1]</sup>Nor study he took;<span style="background-color:#d8daef;"> lovers the</span><sup>[1]</sup>re's
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.293959973335266 Precision: 0.61064453125
# <br>    The ex</span><sup>[1]</sup>cuse with
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.2906631383895875 Precision: 0.60693359375
# <br>  OF WA
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.2875648727416993 Precision: 0.6037109375
# <br>    </span><sup>[1]</sup>Unti<span style="background-color:#d8daef;">l thought </span><sup>[1]</sup>and trys
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.2853244881629944 Precision: 0.61064453125
# <br></span><sup>[1]</sup>Did came him
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.279796021938324 Precision: 0.612109375
# <br>  RICHARD. </span><sup>[1]</sup><span style="background-color:#d8daef;">I have sum</span><sup>[1]</sup>'t on't.
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.2811073250770568 Precision: 0.60849609375
# <br>    Than e</span><sup>[1]</sup>re he m
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.277353618144989 Precision: 0.61162109375
# <br>    </span><sup>[1]</sup>Or none paint
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.2742029604911804 Precision: 0.6134765625
# <br>Admir’d </span><sup>[1]</sup>sigh, my puis
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.268563380241394 Precision: 0.60634765625
# <br>    </span><sup>[1]</sup><span style="background-color:#d8daef;">       Not </span><sup>[1]</sup>your
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.2704424510002137 Precision: 0.60908203125
# <br> [_D</span><sup>[1]</sup>own a<span style="background-color:#d8daef;"> news and </span><sup>[1]</sup>Gallia.
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.2676051445007324 Precision: 0.60205078125
# <br><span style="background-color:#d8daef;">fled with </span><sup>[1]</sup>you<span style="background-color:#d8daef;"> like you not</span><sup>[1]</sup>
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.264794282913208 Precision: 0.61513671875
# <br>FALS</span><sup>[1]</sup>
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.2612366361618041 Precision: 0.617578125
# <br>    If </span><sup>[1]</sup><span style="background-color:#d8daef;">he love me to m</span><sup>[1]</sup>y
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.2609120292663574 Precision: 0.62705078125
# <br>  </span><sup>[1]</sup><span style="background-color:#d8daef;">CORIOLANUS</span><sup>[1]</sup>
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.257060541152954 Precision: 0.61005859375
# <br>    Fo</span><sup>[1]</sup>
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.2551992144584656 Precision: 0.6251953125
# <br></span><sup>[1]</sup><span style="background-color:#d8daef;">Ay, my lord; </span><sup>[1]</sup>he may entrav’<span style="background-color:#d8daef;">d the heav</span><sup>[1]</sup>y
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.2536875505447387 Precision: 0.62431640625
# <br>O </span><sup>[1]</sup>Englis
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.250656361103058 Precision: 0.61201171875
# <br>SCENE 2. </span><sup>[1]</sup>Rebel- upon. The Fria<span style="background-color:#d8daef;">r KING HENRY THE </span><sup>[1]</sup>MOWT.
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.2514708976745605 Precision: 0.6126953125
# <br>    These </span><sup>[1]</sup>eye's rubning. If<span style="background-color:#d8daef;"> I thank you, h</span><sup>[1]</sup>ardly stabbern
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.2468826050758361 Precision: 0.61455078125
# <br>    Sore</span><sup>[1]</sup><span style="background-color:#d8daef;"> our old a</span><sup>[1]</sup><span style="background-color:#d8daef;">nother's h</span><sup>[1]</sup>and.
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.2434534072875976 Precision: 0.6275390625
# <br></span><sup>[1]</sup>Wilt tho
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.245025978088379 Precision: 0.6115234375
# <br>    And bo</span><sup>[1]</sup><span style="background-color:#d8daef;">ught my ma</span><sup>[1]</sup>n, you, s
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.2434160089492798 Precision: 0.60830078125
# <br>Where</span><sup>[1]</sup>'
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.2413553609848023 Precision: 0.6119140625
# <br>    </span><sup>[1]</sup>Be gate-profess<span style="background-color:#d8daef;">. Here's an</span><sup>[1]</sup>
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.236811535358429 Precision: 0.62236328125
# <br>    </span><sup>[1]</sup>Sir, if
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.237205258846283 Precision: 0.61689453125
# <br>
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.2365548753738402 Precision: 0.6328125
# <br>    And pat</span><sup>[1]</sup>ch a t
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.2324037365913392 Precision: 0.63427734375
# <br>As they </span><sup>[1]</sup>ha<span style="background-color:#d8daef;">ve a soldier</span><sup>[1]</sup> by, b
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.2327389097213746 Precision: 0.61875
# <br></span><sup>[1]</sup>I
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.2309629244804383 Precision: 0.60986328125
# <br></span><sup>[1]</sup>
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.2271036033630371 Precision: 0.626953125
# <br>        </span><sup>[1]</sup>
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.2306803307533265 Precision: 0.612890625
# <br> [_Exeunt Attendants</span><sup>[1]</sup>, Cl
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.224728513240814 Precision: 0.6173828125
# <br>    T</span><sup>[1]</sup><span style="background-color:#d8daef;">hink you s</span><sup>[1]</sup>tands li
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.2218732109069825 Precision: 0.6185546875
# <br>I do
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.2214697794914247 Precision: 0.62294921875
# <br>    Th</span><sup>[1]</sup><span style="background-color:#d8daef;">e rather b</span><sup>[1]</sup><span style="background-color:#d8daef;">eing then </span><sup>[1]</sup>have the
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.2230288333892823 Precision: 0.62900390625
# <br>CRES</span><sup>[1]</sup>
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.219960021018982 Precision: 0.63017578125
# <br>Your voice</span><sup>[1]</sup><span style="background-color:#d8daef;">, though the r</span><sup>[1]</sup>emaine
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.2190384187698364 Precision: 0.61396484375
# <br>    Be </span><sup>[1]</sup><span style="background-color:#d8daef;">so far as </span><sup>[1]</sup>if<span style="background-color:#d8daef;"> thou, but </span><sup>[1]</sup>now<span style="background-color:#d8daef;"> thou mightst </span><sup>[1]</sup>
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.2183401141166688 Precision: 0.61591796875
# <br>Hold damne<span style="background-color:#d8daef;">d knave, I have </span><sup>[1]</sup>sold
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.216660062789917 Precision: 0.62958984375
# <br></span><sup>[1]</sup>But need<span style="background-color:#d8daef;">e my man’s </span><sup>[1]</sup>one, so r
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.2168455276489258 Precision: 0.625390625
# <br>   So bu
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.2131704607009888 Precision: 0.634765625
# <br>So holy<span style="background-color:#d8daef;">. I do not t</span><sup>[1]</sup>w<span style="background-color:#d8daef;">o counsel </span><sup>[1]</sup><span style="background-color:#d8daef;">of all this </span><sup>[1]</sup>co
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.211466220855713 Precision: 0.615625
# <br>  PHILOTUS. </span><sup>[1]</sup>Go, hin
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.210780891418457 Precision: 0.6240234375
# <br>  For fr</span><sup>[1]</sup>iends,
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.2114899725914001 Precision: 0.63037109375
# <br>  </span><sup>[1]</sup><span style="background-color:#d8daef;">THIRD GENTLEMAN. S</span><sup>[1]</sup>ho<span style="background-color:#d8daef;">rt, the he</span><sup>[1]</sup>ir<span style="background-color:#d8daef;">, I humbly</span><sup>[1]</sup>.
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.208860357284546 Precision: 0.62275390625
# <br>    B</span><sup>[1]</sup>ut<span style="background-color:#d8daef;"> who gave </span><sup>[1]</sup>him on, as diviney
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.2094458994865418 Precision: 0.62529296875
# <br>T
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.2079046516418457 Precision: 0.626953125
# <br>    T</span><sup>[1]</sup><span style="background-color:#d8daef;">o distribut</span><sup>[1]</sup>
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.2039598898887633 Precision: 0.63271484375
# <br>    And p</span><sup>[1]</sup>r
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.2075602850914002 Precision: 0.640234375
# <br> half
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.2042218565940856 Precision: 0.62060546875
# <br></span><sup>[1]</sup>Where blest. Beg<span style="background-color:#d8daef;">et, brave </span><sup>[1]</sup>M
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.2036804928779603 Precision: 0.63232421875
# <br>Both the</span><sup>[1]</sup>n<span style="background-color:#d8daef;"> I know be</span><sup>[1]</sup>hol<span style="background-color:#d8daef;">d unto my </span><sup>[1]</sup>dear's asp
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.2002779693603516 Precision: 0.63857421875
# <br>  POUR
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1999722185134887 Precision: 0.6234375
# <br></span><sup>[1]</sup><span style="background-color:#d8daef;">  MRS. PAGE. I </span><sup>[1]</sup>sha
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.2006292839050292 Precision: 0.634765625
# <br>I</span><sup>[1]</sup>
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.2001281580924987 Precision: 0.6212890625
# <br>    </span><sup>[1]</sup>Trield<span style="background-color:#d8daef;"> unto our s</span><sup>[1]</sup>ine<span style="background-color:#d8daef;">wn hands, </span><sup>[1]</sup>he
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1979000740051269 Precision: 0.6341796875
# <br>Follows </span><sup>[1]</sup>h
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1956218242645265 Precision: 0.62470703125
# <br>I </span><sup>[1]</sup>let
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1981484413146972 Precision: 0.63603515625
# <br>  </span><sup>[1]</sup>WOLSEY.
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1940227813720703 Precision: 0.61884765625
# <br></span><sup>[1]</sup>
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1938928060531617 Precision: 0.6353515625
# <br>
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.191798403263092 Precision: 0.63544921875
# <br>    </span><sup>[1]</sup><span style="background-color:#d8daef;">I have made </span><sup>[1]</sup>we do to he
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1906272459030152 Precision: 0.6408203125
# <br>Was your</span><sup>[1]</sup> inhookedy sett<span style="background-color:#d8daef;">ers, I would </span><sup>[1]</sup>ha
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.191455096244812 Precision: 0.6228515625
# <br>  Suffolty
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1883676109313965 Precision: 0.62626953125
# <br>Pluck'd </span><sup>[1]</sup>natu<span style="background-color:#d8daef;">re, should </span><sup>[1]</sup>i
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1902928609848022 Precision: 0.6244140625
# <br>He</span><sup>[1]</sup>ar your festin<span style="background-color:#d8daef;">ance. The </span><sup>[1]</sup>mutufian<span style="background-color:#d8daef;"> man, if I </span><sup>[1]</sup>wa
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1916629514694215 Precision: 0.6294921875
# <br>    </span><sup>[1]</sup><span style="background-color:#d8daef;">  Let all </span><sup>[1]</sup>I speak
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1875650119781493 Precision: 0.636328125
# <br>    Frown</span><sup>[1]</sup> means found afficed p
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1859152102470398 Precision: 0.62890625
# <br>    Write </span><sup>[1]</sup>envy I hold! N<span style="background-color:#d8daef;">o, Margare</span><sup>[1]</sup>
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.187756332397461 Precision: 0.63642578125
# <br>So </span><sup>[1]</sup>e
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1847564449310304 Precision: 0.64130859375
# <br>’T<span style="background-color:#d8daef;">is valiant </span><sup>[1]</sup>Palamo<span style="background-color:#d8daef;">n; I am th</span><sup>[1]</sup>y or<span style="background-color:#d8daef;">der water, </span><sup>[1]</sup>
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1835960869789124 Precision: 0.63369140625
# <br>    </span><sup>[1]</sup>S<span style="background-color:#d8daef;">ome truth </span><sup>[1]</sup><span style="background-color:#d8daef;">been too long </span><sup>[1]</sup>with you
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1831025733947753 Precision: 0.63388671875
# </span><sup>[1]</sup>
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1823793902397155 Precision: 0.6421875
# <br>    </span><sup>[1]</sup>Than h<span style="background-color:#d8daef;">e to-night</span><sup>[1]</sup>-shiel
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.182653230190277 Precision: 0.62841796875
# <br></span><sup>[1]</sup>h<span style="background-color:#d8daef;">erself the </span><sup>[1]</sup>
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1813934631347656 Precision: 0.6431640625
# <br>Why that </span><sup>[1]</sup>low maiden
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.18020378780365 Precision: 0.63466796875
# <br>To ha</span><sup>[1]</sup>ve mer
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1768303337097168 Precision: 0.64404296875
# <br>    </span><sup>[1]</sup><span style="background-color:#d8daef;">Give your </span><sup>[1]</sup>own danger<span style="background-color:#d8daef;">s swift to</span><sup>[1]</sup>
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1803958902359009 Precision: 0.62470703125
# <br>    Is C</span><sup>[1]</sup><span style="background-color:#d8daef;">edious is </span><sup>[1]</sup>not
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1805668187141418 Precision: 0.63037109375
# <br>Charm<span style="background-color:#d8daef;">ed hath th</span><sup>[1]</sup>inking to
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1762813992500305 Precision: 0.6455078125
# <br>The s</span><sup>[1]</sup>a
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1765143780708314 Precision: 0.62705078125
# <br>Before </span><sup>[1]</sup>no won<span style="background-color:#d8daef;"> prevail’d</span><sup>[1]</sup><span style="background-color:#d8daef;">. Send me </span><sup>[1]</sup><span style="background-color:#d8daef;">i’ th’ war</span><sup>[1]</sup>l
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1763078570365906 Precision: 0.634375
# <br>And f</span><sup>[1]</sup><span style="background-color:#d8daef;">orbear this </span><sup>[1]</sup>s<span style="background-color:#d8daef;">ong labour</span><sup>[1]</sup>ed sle
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1763301029205322 Precision: 0.637109375
# <br>  ROSALIND. W</span><sup>[1]</sup><span style="background-color:#d8daef;">e will not</span><sup>[1]</sup>
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1765989856719972 Precision: 0.6388671875
# <br>         </span><sup>[1]</sup>At fixe
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1728280606269836 Precision: 0.64716796875
# <br>    </span><sup>[1]</sup>Eassafam'd vaul
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.175449453830719 Precision: 0.64150390625
# <br>But who </span><sup>[1]</sup>was onward yet<span style="background-color:#d8daef;"> do make my</span><sup>[1]</sup> cou
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.172529100894928 Precision: 0.63740234375
# <br>    </span><sup>[1]</sup><span style="background-color:#d8daef;">Till it hat</span><sup>[1]</sup>
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.173108594894409 Precision: 0.63779296875
# <br>[_To Al</span><sup>[1]</sup>on<span style="background-color:#d8daef;">so; and the </span><sup>[1]</sup>regal<span style="background-color:#d8daef;">s, and is </span><sup>[1]</sup>open as a latter throward, urg<span style="background-color:#d8daef;">’d from the</span><sup>[1]</sup>e; from
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1702784023284911 Precision: 0.63271484375
# <br> </span><sup>[1]</sup>
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1711036620140076 Precision: 0.63837890625
# <br>    </span><sup>[1]</sup><span style="background-color:#d8daef;">That thou be</span><sup>[1]</sup>auty in Lestr
# ...
# <br>ANTONY.</span><sup>[1]</sup><span style="background-color:#d8daef;"> Come on, b</span><sup>[1]</sup>
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1434314045906067 Precision: 0.65087890625
# <br>    </span><sup>[1]</sup><span style="background-color:#d8daef;">When these </span><sup>[1]</sup><span style="background-color:#d8daef;">have greater </span><sup>[1]</sup><span style="background-color:#d8daef;">slumbers, </span><sup>[1]</sup>cont
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1399984936714171 Precision: 0.64619140625
# <br>    Ha</span><sup>[1]</sup>ve I im<span style="background-color:#d8daef;">pos'd against </span><sup>[1]</sup>t
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.139115396976471 Precision: 0.64189453125
# <br>And </span><sup>[1]</sup>here<span style="background-color:#d8daef;"> she quickly </span><sup>[1]</sup>al<span style="background-color:#d8daef;">l toward h</span><sup>[1]</sup>ead on us? Sip hold
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.139301691532135 Precision: 0.65087890625
# <br>’Tis fit at game.
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1394615168571471 Precision: 0.6416015625
# <br>    Th</span><sup>[1]</sup>at match
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1388295049667359 Precision: 0.6482421875
# </span><sup>[1]</sup>
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1377213006019593 Precision: 0.640625
# <br>What </span><sup>[1]</sup><span style="background-color:#d8daef;">remembrance</span><sup>[1]</sup>?
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.135403344631195 Precision: 0.65029296875
# <br> Enter </span><sup>[1]</sup>Dunsinan
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1376732864379884 Precision: 0.64912109375
# <br>    And th</span><sup>[1]</sup>at I'll cor
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.13677170753479 Precision: 0.65009765625
# <br></span><sup>[1]</sup>
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1355699400901795 Precision: 0.645703125
# <br>    I </span><sup>[1]</sup><span style="background-color:#d8daef;">have right </span><sup>[1]</sup><span style="background-color:#d8daef;">on me, thou </span><sup>[1]</sup><span style="background-color:#d8daef;">art not no</span><sup>[1]</sup>w s
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1355364990234376 Precision: 0.65078125
# <br>  </span><sup>[1]</sup><span style="background-color:#d8daef;">BUCKINGHAM. </span><sup>[1]</sup>
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1361627850532532 Precision: 0.63564453125
# <br>  FIRST </span><sup>[1]</sup><span style="background-color:#d8daef;">LORD. My lord</span><sup>[1]</sup><span style="background-color:#d8daef;">. This you </span><sup>[1]</sup>first it d
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1327106919288634 Precision: 0.65546875
# <br>       </span><sup>[1]</sup><span style="background-color:#d8daef;">                  </span><sup>[1]</sup>
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1356502957344055 Precision: 0.64248046875
# <br>With de</span><sup>[1]</sup>eds b<span style="background-color:#d8daef;">y no more </span><sup>[1]</sup>mainutions
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1343560853004455 Precision: 0.64921875
# <br> Enter </span><sup>[1]</sup>the Part
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1330626640319825 Precision: 0.64765625
# <br>  </span><sup>[1]</sup> <span style="background-color:#d8daef;"> his lunaci</span><sup>[1]</sup>ance: Simor<span style="background-color:#d8daef;">ise in the </span><sup>[1]</sup>gofts<span style="background-color:#d8daef;"> in it, the</span><sup>[1]</sup>n<span style="background-color:#d8daef;"> if we had </span><sup>[1]</sup>spok
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1313126850128175 Precision: 0.6509765625
# <br>And ma</span><sup>[1]</sup><span style="background-color:#d8daef;">ke my foe </span><sup>[1]</sup>he but my igno<span style="background-color:#d8daef;">ble conceit</span><sup>[1]</sup>.
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1315498871803285 Precision: 0.64677734375
# <br>Now that,<span style="background-color:#d8daef;"> made thin</span><sup>[1]</sup>king!<span style="background-color:#d8daef;"> But, sweet </span><sup>[1]</sup>of estim
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1313760385513305 Precision: 0.640625
# <br>  ABERGAVE</span><sup>[1]</sup>
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1307169346809387 Precision: 0.63759765625
# <br>'And fo</span><sup>[1]</sup>ul again must
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1311377673149108 Precision: 0.6423828125
# <br>  ALLERTIA, aftert
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.131107626914978 Precision: 0.65224609375
# <br></span><sup>[1]</sup>
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1307828822135926 Precision: 0.64072265625
# <br>    </span><sup>[1]</sup><span style="background-color:#d8daef;">And farewell </span><sup>[1]</sup><span style="background-color:#d8daef;">about yours</span><sup>[1]</sup>elves a
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1302334842681885 Precision: 0.649609375
# <br>come to </span><sup>[1]</sup><span style="background-color:#d8daef;">England, d</span><sup>[1]</sup>ow<span style="background-color:#d8daef;">n your goo</span><sup>[1]</sup>r’d ways; tha
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1295686268806457 Precision: 0.63388671875
# <br>
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1298975796699524 Precision: 0.643359375
# <br>    And </span><sup>[1]</sup>w<span style="background-color:#d8daef;">hen again </span><sup>[1]</sup><span style="background-color:#d8daef;">against this hou</span><sup>[1]</sup>rly f
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.130827606678009 Precision: 0.650390625
# <br>A</span><sup>[1]</sup>
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.129229344367981 Precision: 0.65546875
# <br></span><sup>[1]</sup><span style="background-color:#d8daef;">      that </span><sup>[1]</sup>i<span style="background-color:#d8daef;">t were play</span><sup>[1]</sup><span style="background-color:#d8daef;">ing. I am so</span><sup>[1]</sup> day<span style="background-color:#d8daef;">, a poor bo</span><sup>[1]</sup>ld-lakin, an
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1299602818489074 Precision: 0.64140625
# <br>    That </span><sup>[1]</sup>pity<span style="background-color:#d8daef;"> lays upon m</span><sup>[1]</sup>e; in conte
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1259336709976195 Precision: 0.65146484375
# <br>    </span><sup>[1]</sup>I'll t
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.129051558494568 Precision: 0.6515625
# <br>Scene IV. </span><sup>[1]</sup>Gromi
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1284474830627442 Precision: 0.65
# <br>    A</span><sup>[1]</sup>nd err<span style="background-color:#d8daef;">or themselve</span><sup>[1]</sup>
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1281633534431457 Precision: 0.64013671875
# <br>Than chorsely out,<span style="background-color:#d8daef;"> supplied a</span><sup>[1]</sup> thing
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1264382047653199 Precision: 0.659375
# <br>    Arth</span><sup>[1]</sup>lie<span style="background-color:#d8daef;">rs; this th</span><sup>[1]</sup><span style="background-color:#d8daef;">e truth, s</span><sup>[1]</sup>he i
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1266458435058593 Precision: 0.6494140625
# <br>I do desir</span><sup>[1]</sup>
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1265461778640746 Precision: 0.65048828125
# <br>   </span><sup>[1]</sup>
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1270105171203613 Precision: 0.65439453125
# <br>  B</span><sup>[1]</sup><span style="background-color:#d8daef;">UCKINGHAM. A </span><sup>[1]</sup>band- Go,
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1267406611442565 Precision: 0.64990234375
# <br>With<span style="background-color:#d8daef;"> stone as </span><sup>[1]</sup>many<span style="background-color:#d8daef;"> a flatterer</span><sup>[1]</sup>: if I ne<span style="background-color:#d8daef;">ver never </span><sup>[1]</sup><span style="background-color:#d8daef;">saw.       </span><sup>[1]</sup>11416IR
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1261787209510803 Precision: 0.64365234375
# <br>    That </span><sup>[1]</sup>has desi
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1272695956230163 Precision: 0.6435546875
# <br>    In </span><sup>[1]</sup>waste-bar<span style="background-color:#d8daef;">gain: the </span><sup>[1]</sup>curse sees faint: na
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>
# Loss: 1.1243583984375 Precision: 0.64560546875
# <br>
# <small><p style="text-align:right;">Sources: <span style="background-color:#d8daef;">http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/1/0/100/100-0.txt</span><sup>[1]</sup></p></small>

# %% [markdown]
# ## Generate text

# %%
def detectPlagiarism(generatedtext, textlibrary, minQuoteLength=10):
    textlibrary.source_highlight(generatedtext, minQuoteLength)
    
tgen=poet.generate(1000,"\n\n")
detectPlagiarism(tgen, textlib)

# %% [markdown]
# ## Dialog

# %%
# Do a dialog with the recursive neural net trained above:
def doDialog():
    # temperature = 0.6  # 0.1 (frozen character) - 1.3 (creative/chaotic character)
    endPrompt = '.'  # the endPrompt character is the end-mark in answers.
    maxEndPrompts = 4  # look for number of maxEndPrompts until answer is finished.
    maxAnswerSize = 2048  # Maximum length of the answer
    minAnswerSize = 64  # Minimum length of the answer

    
    print("Please enter some dialog.")
    print("The net will answer according to your input.")
    print("'bye' for end,")
    print("'reset' to reset the conversation context,")
    # print("'temperature=<float>' [0.1(frozen)-1.0(creative)]")
    print("    to change character of the dialog.")
    # print("    Current temperature={}.".format(temperature))
    print()
    xso = None
    bye = False
        
    while not bye:
        print("> ", end="")
        prompt = input()
        if prompt == 'bye':
            bye = True
            print("Good bye!")
            continue
        tgen=poet.generate(1000,prompt)
        # print(xso.replace("\\n","\n"))
        textlib.source_highlight(tgen, 10)
    return

# %%
doDialog()

# %%
def save_checkpoint(state, filename='checkpoint.pth.tar', is_best=False):
    torch.save(state, filename)
    if is_best:
        shutil.copyfile(filename, 'model_best.pth.tar')

best_prec1=64.4

save_checkpoint({
            'epoch': e,
            'arch': "poet8",
            'state_dict': poet.state_dict(),
            'best_prec1': best_prec1,
            'optimizer' : opti.state_dict(),
        })
