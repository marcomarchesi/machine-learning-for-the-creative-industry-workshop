# %%
# !ls
# Out:
# sample_data

# %% [markdown]
# # START

# %%
print("Hello")
a = 1
b = 2
print(a+b)
# Out:
# Hello
# 3

# %%
c = 12

# %%
d = 4

# %% [markdown]
# # New Section

# %%
print(c+d+a)
# Out:
# 17
